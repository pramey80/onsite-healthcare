# %%
pip install ollama opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ollama in c:\users\pramey\appdata\roaming\python\python311\site-packages (0.3.1)
# Requirement already satisfied: opencv-python in c:\users\pramey\appdata\roaming\python\python311\site-packages (4.10.0.84)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: numpy>=1.21.2 in e:\anconda\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: anyio in e:\anconda\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.2.0)
# Requirement already satisfied: certifi in e:\anconda\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\pramey\appdata\roaming\python\python311\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: idna in c:\users\pramey\appdata\roaming\python\python311\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2.10)
# Requirement already satisfied: sniffio in e:\anconda\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)

# %%
import cv2
import ollama
import matplotlib.pyplot as plt


image_path = "C:\\Users\\pramey\\OneDrive\\Pictures\\Screenshots\\2022-11-21 (2).png"
image = cv2.imread(image_path)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')  # Hide the axes
plt.show()


text_to_translate = "Your extracted text here"

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-1.40.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\anconda\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\anconda\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from openai) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp311-none-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in e:\anconda\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in e:\anconda\lib\site-packages (from openai) (4.65.0)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: certifi in e:\anconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\pramey\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\pramey\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in e:\anconda\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.40.3-py3-none-any.whl (360 kB)
#    ---------------------------------------- 0.0/360.7 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/360.7 kB ? eta -:--:--
#    ------------------ --------------------- 163.8/360.7 kB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 194.6/360.7 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  358.4/360.7 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 360.7/360.7 kB 1.9 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp311-none-win_amd64.whl (191 kB)
#    ---------------------------------------- 0.0/191.0 kB ? eta -:--:--
#    --------------------- ------------------ 102.4/191.0 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 191.0/191.0 kB 2.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, jiter, openai
# Successfully installed jiter-0.5.0 openai-1.40.3 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script openai.exe is installed in 'C:\Users\pramey\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.8.2 which is incompatible.

# %%
import ollama
client = ollama.Client()
print(dir(client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_client', '_create_blob', '_parse_modelfile', '_request', '_request_stream', '_stream', 'chat', 'copy', 'create', 'delete', 'embed', 'embeddings', 'generate', 'list', 'ps', 'pull', 'push', 'show']
